# %%
import streamlit as st
import feedparser
import trafilatura
import time
from dateutil import parser
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import openai   # optional: used only if you provide API key
import math
import os

# %%
def search_google_news(query, region="IN", lang="en-IN"):
    query=query.replace(' ', '+')
    rss_url = f"https://news.google.com/rss/search?q={query}&hl={lang}&gl={region}&ceid={region}:en"
    feed = feedparser.parse(rss_url)
    return feed.entries

# %%
def resolve_real_url(google_url, headless=True):
    chrome_options = Options()
    if headless:
        chrome_options.add_argument("--headless=new")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--window-size=1920,1080")

    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    try:
        driver.get(google_url)
        time.sleep(1.2)  # usually enough; increase slightly if needed
        return driver.current_url
    except Exception as e:
        print("resolve_real_url error:", e)
        return google_url
    finally:
        driver.quit()

# %%
def extract_text(url):
    try:
        downloaded = trafilatura.fetch_url(url)
        if downloaded:
            text = trafilatura.extract(downloaded)
            return text
    except Exception as e:
        print("extract_text error:", e)
    return None

# %%
search = input("Enter your search query: ")
articles = search_google_news(search)

# %%
real_url= resolve_real_url(articles[0].link)

# %%
text = extract_text(real_url)

# %%
articles[0]["content"] = text

# %%
articles[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'summary', 'summary_detail', 'source', 'content'])

# %%
def search_google_news(query, region="IN", lang="en-IN"):
    query=query.replace(' ', '+')
    rss_url = f"https://news.google.com/rss/search?q={query}&hl={lang}&gl={region}&ceid={region}:en"
    feed = feedparser.parse(rss_url)
    return feed.entries
def resolve_real_url(google_url, headless=True):
    chrome_options = Options()
    if headless:
        chrome_options.add_argument("--headless=new")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--window-size=1920,1080")

    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    try:
        driver.get(google_url)
        time.sleep(1.2)  # usually enough; increase slightly if needed
        return driver.current_url
    except Exception as e:
        print("resolve_real_url error:", e)
        return google_url
    finally:
        driver.quit()
def extract_text(url):
    try:
        downloaded = trafilatura.fetch_url(url)
        if downloaded:
            text = trafilatura.extract(downloaded)
            return text
    except Exception as e:
        print("extract_text error:", e)
    return None
